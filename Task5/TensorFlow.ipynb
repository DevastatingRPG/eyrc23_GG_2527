# %%
import matplotlib.pyplot as plt
# import numpy as np
# import os
import tensorflow as tf
# import tensorflow_hub as hub
# from tensorflow.keras import layers
# Out:
# WARNING:tensorflow:From C:\Users\devas\AppData\Roaming\Python\Python39\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from pathlib import Path

data_path = Path("data")
image_path = data_path / "war_events"
train_dir = image_path / "train"
validation_dir = image_path / "test"

train_dir, validation_dir
output_dir = 'output'

# %%
BATCH_SIZE = 32
IMG_SIZE = (224, 224)

train_dataset = tf.keras.utils.image_dataset_from_directory(train_dir,
                                                            shuffle=True,
                                                            batch_size=BATCH_SIZE,
                                                            image_size=IMG_SIZE)
# Out:
# Found 474 files belonging to 5 classes.

# %%
validation_dataset = tf.keras.utils.image_dataset_from_directory(validation_dir,
                                                                 shuffle=True,
                                                                 batch_size=BATCH_SIZE,
                                                                 image_size=IMG_SIZE)
# Out:
# Found 125 files belonging to 5 classes.

# %%
class_names = train_dataset.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
# efficientnet_url = "https://tfhub.dev/tensorflow/efficientnet/b0/feature-vector/1"

# %%
# def create_model(model_url, num_classes=5):
#   """Takes a TensorFlow Hub URL and creates a Keras Sequential model with it.
  
#   Args:
#     model_url (str): A TensorFlow Hub feature extraction URL.
#     num_classes (int): Number of output neurons in output layer,
#       should be equal to number of target classes, default 10.

#   Returns:
#     An uncompiled Keras Sequential model with model_url as feature
#     extractor layer and Dense output layer with num_classes outputs.
#   """
#   # Download the pretrained model and save it as a Keras layer
#   feature_extractor_layer = hub.KerasLayer(model_url,
#                                            trainable=True, # freeze the underlying patterns
#                                            name='feature_extraction_layer',
#                                            input_shape=IMG_SIZE+(3,)) # define the input image shape
  
#   # Create our own model
#   model = tf.keras.Sequential([
#     feature_extractor_layer, # use the feature extraction layer as the base
#     layers.Dense(num_classes, activation='softmax', name='output_layer') # create our own output layer      
#   ])

#   return model

# %%
# resnet_model = create_model(efficientnet_url, num_classes=5)

# # Compile
# resnet_model.compile(loss='sparse_categorical_crossentropy',
#                      optimizer=tf.keras.optimizers.SGD(),
#                      metrics=['accuracy'])

# %%
# Fit the model
# resnet_history = resnet_model.fit(train_dataset,
#                                   epochs=100,
#                                   steps_per_epoch=len(train_dataset),
#                                   validation_data=validation_dataset,
#                                   validation_steps=len(validation_dataset))

# %%
# resnet_model.save("eff", save_format='tf')

# %%
# resnet_model.save("eff.tf")

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal'),
  tf.keras.layers.RandomRotation(0.2),
  tf.keras.layers.RandomZoom(0.2),
  # tf.keras.layers.RandomTranslation(0.2, 0.2),
])
# Out:
# WARNING:tensorflow:From C:\Users\devas\AppData\Roaming\Python\Python39\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
for image, _ in train_dataset.take(1):
  plt.figure(figsize=(10, 10))
  first_image = image[0]
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
    plt.imshow(augmented_image[0] / 255)
    plt.axis('off')

# %%
preprocess_input = tf.keras.applications.mobilenet_v2.preprocess_input
rescale = tf.keras.layers.Rescaling(1./127.5, offset=-1)

# %%
IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
# Out:
# WARNING:tensorflow:From C:\Users\devas\AppData\Roaming\Python\Python39\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.

# %%
image_batch, label_batch = next(iter(train_dataset))
feature_batch = base_model(image_batch)
print(feature_batch.shape)
# Out:
# (32, 7, 7, 1280)

# %%
base_model.trainable = False

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (32, 1280)

# %%
prediction_layer = tf.keras.layers.Dense(5)
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (32, 5)

# %%
inputs = tf.keras.Input(shape=(224, 224, 3))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x, training=True)
x = global_average_layer(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = prediction_layer(x)
model = tf.keras.Model(inputs, outputs)

# %%
base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=base_learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=[tf.keras.metrics.SparseCategoricalAccuracy(name='accuracy')])

# %%
initial_epochs = 50

# %%
history = model.fit(train_dataset,
                    epochs=initial_epochs,
                    validation_data=validation_dataset)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\devas\AppData\Roaming\Python\Python39\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 15/15 [==============================] - 15s 714ms/step - loss: 1.9940 - accuracy: 0.2194 - val_loss: 1.6578 - val_accuracy: 0.2240
# Epoch 2/50
# 15/15 [==============================] - 10s 630ms/step - loss: 1.8364 - accuracy: 0.2553 - val_loss: 1.6388 - val_accuracy: 0.2400
# Epoch 3/50
# 15/15 [==============================] - 9s 587ms/step - loss: 1.9427 - accuracy: 0.2046 - val_loss: 1.6211 - val_accuracy: 0.2400
# Epoch 4/50
# 15/15 [==============================] - 9s 579ms/step - loss: 1.8731 - accuracy: 0.2215 - val_loss: 1.6052 - val_accuracy: 0.2560
# Epoch 5/50
# 15/15 [==============================] - 9s 559ms/step - loss: 1.8894 - accuracy: 0.2405 - val_loss: 1.5907 - val_accuracy: 0.2480
# Epoch 6/50
# 15/15 [==============================] - 9s 560ms/step - loss: 1.8738 - accuracy: 0.2004 - val_loss: 1.5761 - val_accuracy: 0.2720
# Epoch 7/50
# 15/15 [==============================] - 9s 550ms/step - loss: 1.7523 - accuracy: 0.2658 - val_loss: 1.5626 - val_accuracy: 0.2720
# Epoch 8/50
# 15/15 [==============================] - 9s 560ms/step - loss: 1.8008 - accuracy: 0.2489 - val_loss: 1.5497 - val_accuracy: 0.2800
# Epoch 9/50
# 15/15 [==============================] - 9s 591ms/step - loss: 1.8033 - accuracy: 0.2658 - val_loss: 1.5372 - val_accuracy: 0.2800
# Epoch 10/50
# 15/15 [==============================] - 10s 602ms/step - loss: 1.7013 - accuracy: 0.2932 - val_loss: 1.5250 - val_accuracy: 0.2880
# Epoch 11/50
# 15/15 [==============================] - 10s 645ms/step - loss: 1.7171 - accuracy: 0.2869 - val_loss: 1.5121 - val_accuracy: 0.2880
# Epoch 12/50
# 15/15 [==============================] - 9s 553ms/step - loss: 1.7635 - accuracy: 0.2848 - val_loss: 1.4997 - val_accuracy: 0.2880
# Epoch 13/50
# 15/15 [==============================] - 9s 559ms/step - loss: 1.6825 - accuracy: 0.2996 - val_loss: 1.4886 - val_accuracy: 0.3040
# Epoch 14/50
# 15/15 [==============================] - 9s 561ms/step - loss: 1.6719 - accuracy: 0.2932 - val_loss: 1.4777 - val_accuracy: 0.3200
# Epoch 15/50
# 15/15 [==============================] - 10s 630ms/step - loss: 1.6243 - accuracy: 0.3143 - val_loss: 1.4660 - val_accuracy: 0.3280
# Epoch 16/50
# 15/15 [==============================] - 11s 667ms/step - loss: 1.6685 - accuracy: 0.3186 - val_loss: 1.4555 - val_accuracy: 0.3280
# Epoch 17/50
# 15/15 [==============================] - 10s 614ms/step - loss: 1.6580 - accuracy: 0.2975 - val_loss: 1.4442 - val_accuracy: 0.3440
# Epoch 18/50
# 15/15 [==============================] - 11s 660ms/step - loss: 1.6642 - accuracy: 0.3312 - val_loss: 1.4328 - val_accuracy: 0.3520
# Epoch 19/50
# 15/15 [==============================] - 10s 626ms/step - loss: 1.6500 - accuracy: 0.3249 - val_loss: 1.4220 - val_accuracy: 0.3520
# Epoch 20/50
# 15/15 [==============================] - 10s 613ms/step - loss: 1.6031 - accuracy: 0.2975 - val_loss: 1.4101 - val_accuracy: 0.3600
# Epoch 21/50
# 15/15 [==============================] - 9s 570ms/step - loss: 1.6243 - accuracy: 0.2996 - val_loss: 1.3991 - val_accuracy: 0.3600
# Epoch 22/50
# 15/15 [==============================] - 9s 578ms/step - loss: 1.5574 - accuracy: 0.3460 - val_loss: 1.3888 - val_accuracy: 0.3600
# Epoch 23/50
# 15/15 [==============================] - 9s 579ms/step - loss: 1.5785 - accuracy: 0.3481 - val_loss: 1.3784 - val_accuracy: 0.3600
# Epoch 24/50
# 15/15 [==============================] - 9s 578ms/step - loss: 1.5424 - accuracy: 0.3713 - val_loss: 1.3679 - val_accuracy: 0.3840
# Epoch 25/50
# 15/15 [==============================] - 9s 576ms/step - loss: 1.5355 - accuracy: 0.3397 - val_loss: 1.3570 - val_accuracy: 0.3920
# Epoch 26/50
# 15/15 [==============================] - 9s 568ms/step - loss: 1.5125 - accuracy: 0.3776 - val_loss: 1.3475 - val_accuracy: 0.4080
# Epoch 27/50
# 15/15 [==============================] - 9s 575ms/step - loss: 1.5825 - accuracy: 0.3291 - val_loss: 1.3377 - val_accuracy: 0.4160
# Epoch 28/50
# 15/15 [==============================] - 9s 573ms/step - loss: 1.5239 - accuracy: 0.3650 - val_loss: 1.3276 - val_accuracy: 0.4160
# Epoch 29/50
# 15/15 [==============================] - 9s 570ms/step - loss: 1.4410 - accuracy: 0.3840 - val_loss: 1.3170 - val_accuracy: 0.4160
# Epoch 30/50
# 15/15 [==============================] - 9s 578ms/step - loss: 1.5328 - accuracy: 0.3502 - val_loss: 1.3075 - val_accuracy: 0.4240
# Epoch 31/50
# 15/15 [==============================] - 9s 566ms/step - loss: 1.4666 - accuracy: 0.3861 - val_loss: 1.2977 - val_accuracy: 0.4480
# Epoch 32/50
# 15/15 [==============================] - 9s 565ms/step - loss: 1.4614 - accuracy: 0.3945 - val_loss: 1.2888 - val_accuracy: 0.4720
# Epoch 33/50
# 15/15 [==============================] - 9s 585ms/step - loss: 1.5032 - accuracy: 0.3903 - val_loss: 1.2787 - val_accuracy: 0.4880
# Epoch 34/50
# 15/15 [==============================] - 9s 573ms/step - loss: 1.4522 - accuracy: 0.3945 - val_loss: 1.2701 - val_accuracy: 0.4880
# Epoch 35/50
# 15/15 [==============================] - 10s 600ms/step - loss: 1.4427 - accuracy: 0.4030 - val_loss: 1.2611 - val_accuracy: 0.4880
# Epoch 36/50
# 15/15 [==============================] - 10s 608ms/step - loss: 1.4075 - accuracy: 0.4156 - val_loss: 1.2524 - val_accuracy: 0.5040
# Epoch 37/50
# 15/15 [==============================] - 9s 581ms/step - loss: 1.4150 - accuracy: 0.4135 - val_loss: 1.2430 - val_accuracy: 0.5040
# Epoch 38/50
# 15/15 [==============================] - 9s 567ms/step - loss: 1.3727 - accuracy: 0.4494 - val_loss: 1.2350 - val_accuracy: 0.5040
# Epoch 39/50
# 15/15 [==============================] - 10s 594ms/step - loss: 1.3813 - accuracy: 0.4198 - val_loss: 1.2263 - val_accuracy: 0.5040
# Epoch 40/50
# 15/15 [==============================] - 11s 671ms/step - loss: 1.3950 - accuracy: 0.4051 - val_loss: 1.2174 - val_accuracy: 0.5120
# Epoch 41/50
# 15/15 [==============================] - 11s 706ms/step - loss: 1.3787 - accuracy: 0.4135 - val_loss: 1.2095 - val_accuracy: 0.5280
# Epoch 42/50
# 15/15 [==============================] - 11s 697ms/step - loss: 1.3245 - accuracy: 0.4262 - val_loss: 1.2016 - val_accuracy: 0.5280
# Epoch 43/50
# 15/15 [==============================] - 10s 622ms/step - loss: 1.3149 - accuracy: 0.4662 - val_loss: 1.1931 - val_accuracy: 0.5360
# Epoch 44/50
# 15/15 [==============================] - 10s 625ms/step - loss: 1.3135 - accuracy: 0.4662 - val_loss: 1.1858 - val_accuracy: 0.5360
# Epoch 45/50
# 15/15 [==============================] - 9s 571ms/step - loss: 1.3288 - accuracy: 0.4831 - val_loss: 1.1776 - val_accuracy: 0.5520
# Epoch 46/50
# 15/15 [==============================] - 9s 579ms/step - loss: 1.2892 - accuracy: 0.4641 - val_loss: 1.1698 - val_accuracy: 0.5520
# Epoch 47/50
# 15/15 [==============================] - 9s 586ms/step - loss: 1.3572 - accuracy: 0.4599 - val_loss: 1.1615 - val_accuracy: 0.5600
# Epoch 48/50
# 15/15 [==============================] - 9s 577ms/step - loss: 1.2697 - accuracy: 0.4916 - val_loss: 1.1526 - val_accuracy: 0.5600
# Epoch 49/50
# 15/15 [==============================] - 9s 576ms/step - loss: 1.2797 - accuracy: 0.4810 - val_loss: 1.1446 - val_accuracy: 0.5760
# Epoch 50/50
# 15/15 [==============================] - 9s 578ms/step - loss: 1.3134 - accuracy: 0.4852 - val_loss: 1.1371 - val_accuracy: 0.5760

# %%
base_model.trainable = True

# %%
print("Number of layers in the base model: ", len(base_model.layers))

# Fine-tune from this layer onwards
fine_tune_at = 100

# Freeze all the layers before the `fine_tune_at` layer
for layer in base_model.layers[:fine_tune_at]:
  layer.trainable = False
# Out:
# Number of layers in the base model:  154

# %%
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              optimizer = tf.keras.optimizers.RMSprop(learning_rate=base_learning_rate/10),
              metrics=[tf.keras.metrics.SparseCategoricalAccuracy(name='accuracy')])

# %%
from tensorflow.keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_accuracy', patience=7, verbose=1)

# %%
fine_tune_epochs = 40
total_epochs =  initial_epochs + fine_tune_epochs

history_fine = model.fit(train_dataset,
                         epochs=total_epochs,
                         initial_epoch=history.epoch[-1],
                         validation_data=validation_dataset,
                         callbacks=[es])
# Out:
# Epoch 50/90
# 15/15 [==============================] - 20s 946ms/step - loss: 1.2908 - accuracy: 0.4810 - val_loss: 1.1488 - val_accuracy: 0.5600
# Epoch 51/90
#  5/15 [=========>....................] - ETA: 6s - loss: 1.2152 - accuracy: 0.5250
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 4
#       1 fine_tune_epochs = 40
#       2 total_epochs =  initial_epochs + fine_tune_epochs
# ----> 4 history_fine = model.fit(train_dataset,
#       5                          epochs=total_epochs,
#       6                          initial_epoch=history.epoch[-1],
#       7                          validation_data=validation_dataset,
#       8                          callbacks=[es])
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)
#    1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
model.save("ninetysix.h5")

# %%
# import tensorflow as tf

# # Assuming 'model' is your model
# tf.saved_model.save(model, "data\war_events")
